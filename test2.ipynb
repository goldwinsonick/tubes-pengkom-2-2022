# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("co2_mm_mlo.csv")
print(df)
# Out:
#      year  month  decimal date  average  deseasonalized  ndays  sdev   unc
# 0    1958      3     1958.2027   315.70          314.43     -1 -9.99 -0.99
# 1    1958      4     1958.2877   317.45          315.16     -1 -9.99 -0.99
# 2    1958      5     1958.3699   317.51          314.71     -1 -9.99 -0.99
# 3    1958      6     1958.4548   317.24          315.14     -1 -9.99 -0.99
# 4    1958      7     1958.5370   315.86          315.18     -1 -9.99 -0.99
# ..    ...    ...           ...      ...             ...    ...   ...   ...
# 770  2022      5     2022.3750   420.99          417.60     30  0.76  0.27
# 771  2022      6     2022.4583   420.99          418.62     28  0.30  0.11
# 772  2022      7     2022.5417   418.90          418.56     27  0.57  0.21
# 773  2022      8     2022.6250   417.19          419.15     27  0.34  0.13
# 774  2022      9     2022.7083   415.95          419.48     28  0.41  0.15
#
# [775 rows x 8 columns]

# %%
df.plot(kind="line", x="decimal date", y="average")
# Out:
# <AxesSubplot:xlabel='decimal date'>

# %%
df.loc[(df["decimal date"] > 1990) & (df["decimal date"] < 2010)].plot(kind="line", x="decimal date", y = "average")
# Out:
# <AxesSubplot:xlabel='decimal date'>
